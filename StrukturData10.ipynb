# %%
#Hash Table sederhana
class SimpleHashTable:
  def __init__(self, size):
    self.size = size
    self.table = [None] * size

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    self.table[index] = value

  def search(self, key):
    index = self.hash_function(key)
    return self.table[index]

#Contoh
ht = SimpleHashTable(10)
ht.insert('Apel',100)
ht.insert('Pisang',200)

print('Nilai untuk "Apel" :', ht.search('Apel'))
print('Nilai untuk "Pisang" :', ht.search('Pisang'))
# Out:
# Nilai untuk "Apel" : 100
# Nilai untuk "Pisang" : 200

# %%
#Penanganan Collision dengan Linear Probing
class LinearProbingHashTable:
  def __init__(self, size):
    self.size = size
    self.table = [None] *size

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    original_index = index

    while self.table[index] is not None:
      if self.table[index] [0] == key:
        break
      index = (index + 1)%self.size
      if index == original_index:
        raise Exception('Hash table penuh')
    self.table[index] = (key, value)

  def search(self, key):
    index = self.hash_function(key)
    original_index= index

    while self.table[index] is not None:
      if self.table[index] [0] == key:
        return self.table[index][1]
      index = (index + 1)%self.size
      if index == original_index:
        break
    return None

#Contoh penggunaan
ht = LinearProbingHashTable(5)
ht.insert('Apel',100)
ht.insert('Pisang',200)
ht.insert('Melon',300)
print('Nilai untuk "Apel":', ht.search('Apel'))
print('Nilai untuk "Melon":', ht.search('Melon'))
# Out:
# Nilai untuk "Apel": 100
# Nilai untuk "Melon": 300

# %%
#Penanganan Collision dengan Chaining
class ChainingHashTable:
  def __init__(self, size):
    self.size = size
    self.table = [[] for _ in range(size)]

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    for i, (k, v) in enumerate(self.table[index]):
      if k == key:
        self.table[index][i] = (key, value)
        return
    self.table[index].append((key, value))

  def search(self, key):
    index = self.hash_function(key)
    for k, v in self.table[index]:
      if k == key:
        return v
    return None

#Contoh
ht = ChainingHashTable(5)
ht.insert('Apel',100)
ht.insert('Pisang',200)
ht.insert('Mewlon',300)
print('Nilai untuk "Apel":', ht.search('Apel'))
print('Nilai untuk "Mewlon":', ht.search('Mewlon'))
# Out:
# Nilai untuk "Apel": 100
# Nilai untuk "Mewlon": 300

# %%
class LinearProbingHashTable:
  def __init__(self, size):
    self.size = size
    self.table = [None] *size

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    original_index = index

    while self.table[index] is not None:
      if self.table[index] [0] == key:
        break
      index = (index + 1)%self.size
      if index == original_index:
        raise Exception('Hash table penuh')
    self.table[index] = (key, value)

  def search(self, key):
    index = self.hash_function(key)
    original_index= index

    while self.table[index] is not None:
      if self.table[index] [0] == key:
        return self.table[index][1]
      index = (index + 1)%self.size
      if index == original_index:
        break
    return None

#Contoh penggunaan
ht = LinearProbingHashTable(5)
ht.insert('A',10)
ht.insert('B',20)
ht.insert('C',40)
ht.insert('D',40)
ht.insert('E',50)
print('Nilai untuk "A":', ht.search('A'))
print('Nilai untuk "B":', ht.search('B'))
print('Nilai untuk "C":', ht.search('C'))
print('Nilai untuk "D":', ht.search('D'))
print('Nilai untuk "E":', ht.search('E'))
# Out:
# Nilai untuk "A": 10
# Nilai untuk "B": 20
# Nilai untuk "C": 40
# Nilai untuk "D": 40
# Nilai untuk "E": 50

# %%
class LinearProbingHashTable:
  def __init__(self, size):
    self.size = size
    self.table = [None] *size

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    original_index = index

    while self.table[index] is not None:
      if self.table[index] [0] == key:
        break
      index = (index + 1)%self.size
      if index == original_index:
        raise Exception('Hash table penuh')
    self.table[index] = (key, value)

  def search(self, key):
    index = self.hash_function(key)
    original_index= index

    while self.table[index] is not None:
      if self.table[index] [0] == key:
        return self.table[index][1]
      index = (index + 1)%self.size
      if index == original_index:
        break
    return None

#Contoh penggunaan
ht = LinearProbingHashTable(5)
ht.insert('Apel',100)
ht.insert('Pisang',200)
ht.insert('Melon',300)
ht.insert('A',10)
ht.insert('B',20)
ht.insert('C',30)
ht.insert('D',40)
ht.insert('E',50)
print('Nilai untuk "Apel":', ht.search('Apel'))
print('Nilai untuk "Melon":', ht.search('Melon'))
print('Nilai untuk "A":', ht.search('A'))
print('Nilai untuk "B":', ht.search('B'))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_1735/834960920.py in <cell line: 0>()
#      38 ht.insert('A',20)
#      39 ht.insert('B',20)
# ---> 40 ht.insert('C',30)
#      41 ht.insert('D',40)
#      42 ht.insert('E',50)
#
# /tmp/ipykernel_1735/834960920.py in insert(self, key, value)
#      16       index = (index + 1)%self.size
#      17       if index == original_index:
# ---> 18         raise Exception('Hash table penuh')
#      19     self.table[index] = (key, value)
#      20
#
# Exception: Hash table penuh

# %%
class LinearProbingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        original_index = index

        while self.table[index] is not None:
            # Jika key sudah ada, perbarui nilainya
            if self.table[index][0] == key:
                break

            index = (index + 1) % self.size
            if index == original_index:
                raise Exception("Hash table penuh")

        self.table[index] = (key, value)

    def search(self, key):
        index = self.hash_function(key)
        original_index = index

        while self.table[index] is not None:
            if self.table[index][0] == key:
                return self.table[index][1]
            index = (index + 1) % self.size
            if index == original_index:
                break
        return None


ht_linear = LinearProbingHashTable(5)

data_to_insert = [("A", 10), ("B", 20), ("C", 30), ("D", 40), ("E", 50)]
for key, value in data_to_insert:
    ht_linear.insert(key, value)


print("Isi table (Linear Probing):")
for i, slot in enumerate(ht_linear.table):
    print(f"Slot {i}: {slot}")
# Out:
# Isi table (Linear Probing):
# Slot 0: ('D', 40)
# Slot 1: ('E', 50)
# Slot 2: ('A', 10)
# Slot 3: ('C', 20)
# Slot 4: ('B', 20)

# %%
class ChainingHashTable:
  def __init__(self, size):
    self.size = size
    self.table = [[] for _ in range(size)]

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    for i, (k, v) in enumerate(self.table[index]):
      if k == key:
        self.table[index][i] = (key, value)
        return
    self.table[index].append((key, value))

  def search(self, key):
    index = self.hash_function(key)
    for k, v in self.table[index]:
      if k == key:
        return v
    return None

#Contoh
ht = ChainingHashTable(3)
ht.insert('Apel',100)
ht.insert('Pisang',200)
ht.insert('Mewlon',300)
ht.insert('Lemon',400)
print('Nilai untuk "Apel":', ht.search('Apel'))
print('Nilai untuk "Mewlon":', ht.search('Mewlon'))
print('Nilai untuk "Pisang":', ht.search('Pisang'))
print('Nilai untuk "Lemon":', ht.search('Lemon'))
# Out:
# Nilai untuk "Apel": 100
# Nilai untuk "Mewlon": 300
# Nilai untuk "Pisang": 200
# Nilai untuk "Lemon": 400

# %%
class ChainingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [[] for _ in range(size)]

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        for i, (k, v) in enumerate(self.table[index]):
            if k == key:
                self.table[index][i] = (key, value)
                return
        self.table[index].append((key, value))

    def search(self, key):
        index = self.hash_function(key)
        for k, v in self.table[index]:
            if k == key:
                return v
        return None

ht_chaining = ChainingHashTable(3)
words = [
    ("apel", 100),
    ("melon", 200),
    ("lemon", 300),
    ("pisang", 400)
    ]
for key, value in words:
    ht_chaining.insert(key, value)

print("Isi table (Chaining):")
for i, slot in enumerate(ht_chaining.table):
    print(f"Slot {i}: {slot}")
# Out:
# Isi table (Chaining):
# Slot 0: [('melon', 200)]
# Slot 1: [('apel', 100), ('lemon', 300), ('pisang', 400)]
# Slot 2: []
